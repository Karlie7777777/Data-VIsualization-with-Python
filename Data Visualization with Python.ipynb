# %%
import matplotlib as mpl

# %%
print('matplotlib version: ', mpl.__version__)
# Out:
# matplotlib version:  3.1.3

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(5,5,'o')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(5,5,'o')

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.plot(5,5,'o')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ### using matplotlib notebook backend, we don't need to draw another plot when we want to add something

# %%
plt.ylabel('Y')
plt.xlabel('X')
plt.title('Plotting Example')
# Out:
# Text(0.5, 1, 'Plotting Example')

# %%
df['China'].plot(kind = 'hist')
df.plot(kind = 'line')

# %% [markdown]
# ## Week 1 M3 V4

# %%
import numpy as np
import pandas as pd

# %%
# !pip install xlrd
print('xlrd installed')
# Out:
# ...
# WARNING: You are using pip version 20.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/Users/xinyifang/opt/anaconda3/bin/python3 -m pip install --upgrade pip' command.
# xlrd installed

# %%
df_can = pd.read_excel('Canada.xlsx','Canada by Citizenship',skiprows = range(20),skip_footer = 2) #skip first 20 rows and last 2 rows
df_can.head(1)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG        RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501  Southern Asia
#
#    DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 0  902  Developing regions    16  ...  2978  3436  3009  2652  2111  1746
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
#
# [1 rows x 43 columns]

# %%
df_can.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013,    'Total'],
#       dtype='object')

# %% [markdown]
# ## Week1 M3 V5

# %%
df_can['Total'] = df_can.iloc[:,-34:].sum(axis=1)
df_can = df_can.set_index('OdName')

# %%
df_can.head(2)
# Out:
#                    Type    Coverage  AREA AreaName   REG          RegName  \
# OdName
# Afghanistan  Immigrants  Foreigners   935     Asia  5501    Southern Asia
# Albania      Immigrants  Foreigners   908   Europe   925  Southern Europe
#
#              DEV             DevName  1980  1981  ...  2005  2006  2007  2008  \
# OdName                                            ...
# Afghanistan  902  Developing regions    16    39  ...  3436  3009  2652  2111
# Albania      901   Developed regions     1     0  ...  1223   856   702   560
#
#              2009  2010  2011  2012  2013  Total
# OdName
# Afghanistan  1746  1758  2203  2635  2004  58639
# Albania       716   561   539   620   603  15699
#
# [2 rows x 43 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

## don't have cleaned data, so can't run
# %matplotlib notebook

yaers = list(map(str, range(1980,2014)))
df_canada.loc['Haiti',years].plot(kind = 'line') # here 'Haiti' is index
plt.title('Immigration from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# ## Week2 M1 V1 Area plot

# %%
years = list(map(int,range(1980,2014)))
df_can.sort_values(['Total'],ascending = False, axis = 0, inplace = True)

# %%
df_can.head(7)
# Out:
#                                                           Type    Coverage  \
# OdName
# Total                                               Immigrants        Both
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Unknown                                             Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
#
#                                                     AREA AreaName   REG  \
# OdName
# Total                                                999    World   999
# India                                                935     Asia  5501
# China                                                935     Asia   906
# ...

# %%
df_can = df_can.drop(['Total','Unknown'])

# %%
df_top5 = df_can.head()
df_top5 = df_top5[years].transpose()
df_top5.head()
# Out:
# OdName  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980     8880   5123                                              22045
# 1981     8670   6682                                              24796
# 1982     8147   3308                                              20620
# 1983     7338   1863                                              10015
# 1984     5704   1527                                              10170
#
# OdName  Philippines  Pakistan
# 1980           6051       978
# 1981           5921       972
# 1982           5249      1201
# 1983           4562       900
# 1984           3801       668

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib notebook
df_top5.plot(kind = 'area')
plt.title('Immigration trend of top 5 countries')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ## Week2 M1 V2 Histograms

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# prepare data
df_can = pd.read_excel('Canada.xlsx','Canada by Citizenship',skiprows = range(20),skip_footer = 2) #skip first 20 rows and last 2 rows
df_can['Total'] = df_can.iloc[:,-34:].sum(axis=1)
df_can = df_can.set_index('OdName')
df_can = df_can.drop(['Total','Unknown'])
df_can.head(1)
# Out:
#                    Type    Coverage  AREA AreaName   REG        RegName  DEV  \
# OdName
# Afghanistan  Immigrants  Foreigners   935     Asia  5501  Southern Asia  902
#
#                         DevName  1980  1981  ...  2005  2006  2007  2008  \
# OdName                                       ...
# Afghanistan  Developing regions    16    39  ...  3436  3009  2652  2111
#
#              2009  2010  2011  2012  2013  Total
# OdName
# Afghanistan  1746  1758  2203  2635  2004  58639
#
# [1 rows x 43 columns]

# %%
df_can[2013].hist(bins = 50)
# Out:
# <img src="data:image/png;base64,..." width="238.88889521728345">

# %%
df_can[2013].plot(kind = 'hist')
plt.title('Histogram of immigration from 195 countries in 2013')
plt.ylabel('Number of countries')
plt.xlabel('Number of Immigrants')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="418.88889998565514">

# %%
# add the bin edges into histogram. There are 10 bins in default
import numpy as np
count, bin_edges = np.histogram(df_can[2013])
df_can[2013].plot(kind = 'hist', xticks = bin_edges)
plt.title('Histogram of immigration from 195 countries in 2013')
plt.ylabel('Number of countries')
plt.xlabel('Number of Immigrants')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="877.7778010309485">

# %%
count, bin_edges
# Out:
# (array([178,  11,   1,   2,   0,   0,   0,   0,   1,   2]),
#  array([    0. ,  3412.9,  6825.8, 10238.7, 13651.6, 17064.5, 20477.4,
#         23890.3, 27303.2, 30716.1, 34129. ]))

# %% [markdown]
# ## Week2 M1 V3
